# %% [markdown]
# <a href="https://colab.research.google.com/github/isacdata/Data_Science/blob/main/Transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 23.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 35.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 42.5 MB/s eta 0:00:00
# ...

# %%
import transformers
from transformers import pipeline

# %%
qea = pipeline('question-answering', model= 'pierreguillou/bert-base-cased-squad-v1.1-portuguese')
# Out:
# ...
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'

# %%
texto = "Carl Sagan foi um cientista norte-americano"
pergunta = 'Quem foi Carl Sagan?'
resposta = qea(question=pergunta, context =texto)
print('Pergunta: ', pergunta)
print('Resposta: ', resposta['answer'])
print('Score: ', resposta['score'])
# Out:
# Pergunta:  Quem foi Carl Sagan?
# Resposta:  cientista norte-americano
# Score:  0.7890549302101135
